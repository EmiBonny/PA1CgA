# %% [markdown]
# <a href="https://colab.research.google.com/github/EmiBonny/PA1CgA/blob/main/23_03_26P_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int (input("Digite um número:"))
b = int (input("Digite um número:"))
if a > b:

  print (f + {a} "maior que" {b >})

# %%
# Escrever um programa que verifica se o úsuario é maior de idade
nome = str (input(" Digite seu nome: "))
idade = int (input(" Digite sua idade: "))

if idade > 18:
  print (f"{nome}, você é maior de idade.")

else:
    print (f"{nome}, você é menor de idade.")
# Out:
#  Digite seu nome: szaoska
#  Digite sua idade: 3444
# szaoska, você é maior de idade.

# %%
#escrever um programa que verifica se um número é par ou impar
numero = int (input("Digite um número: "))

if numero % 2==0:
 print (f"{numero} é um número par.")
else:
 print (f"{numero} é um número impar.")
# Out:
# Digite um número: 44
# 44 é um número par.

# %%
# escrever um programa que verifica uma senha simples, senha -- 1234, saída acesso permitido
senha = 1234
senhadigitada = int (input ("Digite a senha: "))

if senha == senhadigitada:
 print (f"acesso permitido.")
else:
 print (f"senha incorreta, tente novamente.")
 senhadigitada = int (input ("digite a senha: "))

 if senha == senhadigitada:
  print (f"acesso permitido.")
 else:
  print (f"limite de tentativas excedido. Tente novamente mais tarde.")
# Out:
# Digite a senha: 34234
# senha incorreta, tente novamente.
# digite a senha: 1234
# acesso permitido.

# %%
#escrever um programa que verifica se um numero é maior que 10
numero = int (input ("Digite um número: "))

if numero > 10:
  print (f"{numero} é maior que 10.")
else:
  print (f"{numero} é menor que 10.")
# Out:
# Digite um número: 7
# 7 é menor que 10.

# %%
# Escrever um programa que:
# Peça o valor da compra
# Se o valor for maior que 100, aplique um desconto de 10%
# Se não, mostre o valor normal

compra = float (input("Digite o valor da compra: "))

if compra > 100:

  desconto = compra * 0.9
  print (f"O valor da compra com desconto é de R${desconto:.2f}")

else:

  print (f"O valor da compra é de R${compra:.2f}")
# Out:
# Digite o valor da compra: 5
# O valor da compra é de R$5.00

# %%
#escrever um programa que o aluno digita 04 notas dos bimestres e o programa calcula a média e mostra na saída se o aluno foi aprovado, recuperação ou reprovado.
nota1 = float (input ("digite a nota do 1 bimestre: "))
nota2 = float (input ("digite a nota do 2 bimestre: "))
nota3 = float (input ("digite a nota do 3 bimestre: "))
nota4 = float (input ("digite a nota do 4 bimestre: "))
media = (nota1 + nota2 + nota3 + nota4)/4

if media >= 7:
  print (f"você foi aprovado, sua média foi: {media}")
elif media >= 5:
  print (f"você está de recuperação, sua média foi: {media}")
else:
  print (f"você foi reprovado, sua média foi: {media}")
