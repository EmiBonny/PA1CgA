# %% [markdown]
# <a href="https://colab.research.google.com/github/EmiBonny/PA1CgA/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Interações e laços de repetição
print ("Olá mundo!")
print ("Olá mundo!")
print ("Olá mundo!")
print ("Olá mundo!")
print ("Olá mundo!")
# Out:
# Olá mundo!
# Olá mundo!
# Olá mundo!
# Olá mundo!
# Olá mundo!

# %%
for i in range (5):
  print ("Olá mundo!")
# Out:
# Olá mundo!
# Olá mundo!
# Olá mundo!
# Olá mundo!
# Olá mundo!

# %%
for i in range (6):
  print (i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for i in range (1, 6):
 print (i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# Escrever um programa que imprime de 5 até 0
for i in range (7):
  print (6 - i)
# Out:
# 6
# 5
# 4
# 3
# 2
# 1
# 0

# %%
#escrever um programa que imprime os números pares de 0 á 10
for i in range (0, 11, 2):
  print (i)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
#imprimi números impares
for i in range (1, 11, 2):
 print (i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
# Escrever um programa que o usuario digita um numero de 1 a 10 e imprime a tabuada.
num = int (input("Digite um número de 1 a 10: "))
for i in range (1, 11):
 print (f"{num} x {i} = {num * i}")
# Out:
# Digite um número de 1 a 10: 2
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20
